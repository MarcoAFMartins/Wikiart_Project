# %% [markdown]
# # Testing Deep Learning

# %%
import numpy as np
import Tensorflow
import keras
# Out:
# Running cells with 'DL2026 (Python 3.11.15)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n DL2026 ipykernel --update-deps --force-reinstall'
