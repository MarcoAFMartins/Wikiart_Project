# %% [markdown]
# In this notebook our goal is to create a custom model based on each of these architectures:
# - Xception
# - VGG16
# - ResNet
# - Inception
# - MobileNet
# - DenseNet
# - NASNet
# - EfficientNet
# - ConvNext
#
# We should read the papers of each of these architectures, identify what are the breakthroughs of each model and what is the thinking behind each of them.
#
# In the next notebook, we will try to combine what we learned from each of the architectures to our own custom model tailored to our problem, with some of our own ideas to tailor the model to our understanding of the problem.

# %% [markdown]
# Or maybe we should illustrate the narrative of balancing image size (keeping the same number of parameters and adjusting model depth and number of kernels used) and network depth (changing the image size to keep the same number of paremeters)

# %% [markdown]
# We could explore vision transformers as there is no pre-trained vision transformer models in keras, and it would be something neat to explore
