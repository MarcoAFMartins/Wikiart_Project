# %% [markdown]
# # WikiArt Dataset — Exploratory Data Analysis
#
# **Goal:** Understand the dataset deeply before touching any model.
# Every section ends with a written interpretation — not just a plot.
# The last section turns observations into concrete modelling decisions.

# %% [markdown]
# ## Imports & configuration
#
# Load all libraries you'll need and define any global constants (dataset path, random seed, figure size defaults, etc.).

# %%
# Your imports and configuration here

# %% [markdown]
# ---
# ## 1. Dataset loading & first look
#
# > **How to think:** Before anything else, just look at what you have. Orient yourself.

# %% [markdown]
# ### 1.1 Load the dataset
#
# How is the data structured on disk? What format are the files in? What metadata is available alongside the images?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 1.2 Count what you have
#
# Total number of samples. How many unique classes/labels exist? Are there any obvious missing or corrupted files?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 1.3 Display a random sample
#
# Show a grid of images from different classes. Does what you see match what you expected from the dataset description?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ---
# ## 2. Class distribution
#
# > **How to think:** This is the most critical question for a classification task. Imbalance has downstream consequences on training, loss choice, and evaluation.

# %% [markdown]
# ### 2.1 Samples per class
#
# Plot the count for every class. Is the distribution uniform or heavily skewed? Which classes dominate, which are rare?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 2.2 Quantify the imbalance
#
# What is the ratio between the largest and smallest class? At what point does imbalance become a problem for a model?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 2.3 Implications
#
# If a class has very few samples, what could go wrong during training? How might this influence your choice of loss function or evaluation metric?

# %% [markdown]
# *Your written reasoning here — no code needed for this cell.*

# %% [markdown]
# ---
# ## 3. Image properties
#
# > **How to think:** Images are not all the same. Understand what you're actually feeding the model — size, shape, and format inconsistencies all need decisions.

# %% [markdown]
# ### 3.1 Image dimensions
#
# Plot the distribution of widths and heights. Are all images the same size, or do they vary? What does this mean for resizing and information loss?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 3.2 Aspect ratios
#
# Are images square, portrait, or landscape? If you resize everything to a square, what happens to the paintings that aren't?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 3.3 Colour channels
#
# Are all images RGB? Are there any grayscale or RGBA images? How will you handle inconsistencies?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 3.4 File size distribution
#
# Do some images have unusually small file sizes? Could they be low quality, heavily compressed, or corrupted?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ---
# ## 4. Visual characteristics per class
#
# > **How to think:** What makes each class visually distinct — or not? If you can't tell classes apart, the model will struggle too.

# %% [markdown]
# ### 4.1 Display samples per class
#
# Show several examples from each class side by side. Can you, as a human, tell them apart? What visual cues are you using?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 4.2 Mean image per class
#
# Compute and display the average image for each class. Does it reveal something about the dominant colours, compositions, or textures of that class?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 4.3 Hard-to-distinguish pairs
#
# Are there any two classes that look very similar to you? Note them — they will likely be where your model struggles too.

# %% [markdown]
# *Your written reasoning here — note any confusable class pairs and why.*

# %% [markdown]
# ---
# ## 5. Colour & pixel statistics
#
# > **How to think:** Put numbers behind what your eyes see. These statistics directly inform your normalisation strategy.

# %% [markdown]
# ### 5.1 Overall pixel intensity distribution
#
# Is the dataset predominantly dark, light, or balanced? How does this affect normalisation choices?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 5.2 Per-channel mean & standard deviation
#
# Compute the mean and standard deviation for R, G, and B across the whole dataset. Why does a model benefit from knowing these values before training?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 5.3 Colour profile by class
#
# Do certain classes have a distinctive colour palette? Could colour alone partially predict the class, or is it more about texture and composition?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ---
# ## 6. Data quality & potential issues
#
# > **How to think:** Find the problems before the model does. Issues discovered here are cheap to fix — issues discovered after training are expensive.

# %% [markdown]
# ### 6.1 Duplicate or near-duplicate images
#
# Are any images identical or very similar? If duplicates span train and test sets, what problem does that create for your evaluation?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 6.2 Mislabelled or ambiguous samples
#
# Spot-check samples that seem off. Is the label clearly correct? How much noise might the dataset contain, and how does noisy labelling affect training?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ### 6.3 Outliers
#
# Are there any images that are extreme in size, brightness, or appearance? Should they be removed, or treated specially?

# %%
# Your code here

# %% [markdown]
# *Your observations here.*

# %% [markdown]
# ---
# ## 7. Summary & decisions
#
# > **How to think:** Turn observations into concrete choices. This section is what the report will draw from — and what justifies every preprocessing and modelling decision downstream.

# %% [markdown]
# ### 7.1 Key findings
#
# What are the 3–5 most important things you learned about this dataset? Write them out in plain language.

# %% [markdown]
# *Your written summary here.*
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ### 7.2 Decisions driven by the EDA
#
# What will you do differently in preprocessing or modelling because of what you found? Every decision here should trace back to a specific observation above.

# %% [markdown]
# *Your decisions here. Format: **Decision** → because of finding X in section Y.*
#
# -
# -
# -

# %% [markdown]
# ### 7.3 Open questions
#
# What did you discover that you still don't fully understand? What would you investigate further if you had more time?

# %% [markdown]
# *Your open questions here.*
#
# -
# -
